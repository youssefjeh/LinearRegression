# %% [markdown]
# ![1.PNG](data:image/png;base64,...)

# %% [markdown]
# ![image_2022-03-22_111020.png](data:image/png;base64,...)

# %% [markdown]
# ![2.PNG](data:image/png;base64,...)

# %%
import numpy as np
from sklearn.datasets import make_regression
import matplotlib.pyplot as plt

# %% [markdown]
# ![image_2022-03-22_111240.png](data:image/png;base64,...)

# %% [markdown]
# ### Dataset

# %%
x,y = make_regression(n_samples=100,n_features=1,noise=10)
plt.scatter(x,y)

# %%
print(x.shape)
y=y.reshape(y.shape[0],1)
print(y.shape)
# Out:
# (100, 1)
# (100, 1)

# %%
#matrice X
X=np.hstack((x,np.ones(x.shape))
X
# Out:
# array([[-0.11695827,  1.        ],
#        [ 0.21902391,  1.        ],
#        [ 0.38466812,  1.        ],
#        [ 0.26616548,  1.        ],
#        [ 0.16174754,  1.        ],
#        [-0.79408528,  1.        ],
#        [-0.20636277,  1.        ],
#        [-0.21030906,  1.        ],
#        [-1.30954204,  1.        ],
#        [ 0.80925152,  1.        ],
#        [-0.76125376,  1.        ],
#        [-0.51918486,  1.        ],
#        [-1.00915852,  1.        ],
#        [ 0.13922644,  1.        ],
#        [-0.79498302,  1.        ],
#        [-0.43065814,  1.        ],
#        [ 1.97200324,  1.        ],
#        [-1.41179431,  1.        ],
#        [ 0.25710115,  1.        ],
#        [-0.6387444 ,  1.        ],
#        [ 0.9732549 ,  1.        ],
#        [ 0.62253579,  1.        ],
#        [-0.10243468,  1.        ],
#        [-0.89036069,  1.        ],
#        [-0.64097775,  1.        ],
#        [ 0.47016083,  1.        ],
#        [ 1.07891594,  1.        ],
#        [ 0.18214863,  1.        ],
#        [-1.42301332,  1.        ],
#        [-0.79246679,  1.        ],
#        [ 1.21001027,  1.        ],
#        [ 0.42845761,  1.        ],
#        [-0.26039087,  1.        ],
#        [-1.08315936,  1.        ],
#        [ 1.43751412,  1.        ],
#        [ 0.03871954,  1.        ],
#        [ 0.07556015,  1.        ],
#        [-2.10106927,  1.        ],
#        [-0.89267446,  1.        ],
#        [ 0.32578549,  1.        ],
#        [ 0.37209372,  1.        ],
#        [ 0.49242623,  1.        ],
#        [-0.00874076,  1.        ],
#        [ 1.02013271,  1.        ],
#        [ 1.26573595,  1.        ],
#        [ 1.28895425,  1.        ],
#        [-0.86264206,  1.        ],
#        [-0.32221936,  1.        ],
#        [ 0.24902692,  1.        ],
#        [ 0.54827423,  1.        ],
#        [ 1.99360272,  1.        ],
#        [-1.65229814,  1.        ],
#        [-0.79338605,  1.        ],
#        [ 0.46627016,  1.        ],
#        [ 1.20555436,  1.        ],
#        [ 1.0213766 ,  1.        ],
#        [-0.90193755,  1.        ],
#        [-0.31921437,  1.        ],
#        [-1.19681864,  1.        ],
#        [-0.72129217,  1.        ],
#        [ 1.62515796,  1.        ],
#        [ 0.66469242,  1.        ],
#        [ 0.66180192,  1.        ],
#        [ 0.19650647,  1.        ],
#        [-1.12233366,  1.        ],
#        [-0.65317845,  1.        ],
#        [-0.66110026,  1.        ],
#        [ 0.80178482,  1.        ],
#        [-0.57906915,  1.        ],
#        [-1.00239564,  1.        ],
#        [-0.05163044,  1.        ],
#        [-0.02934779,  1.        ],
#        [-0.63641406,  1.        ],
#        [-0.47334758,  1.        ],
#        [ 0.18194803,  1.        ],
#        [ 0.17554961,  1.        ],
#        [ 0.06817038,  1.        ],
#        [-0.69697774,  1.        ],
#        [ 0.83155391,  1.        ],
#        [-0.67612772,  1.        ],
#        [ 0.8313209 ,  1.        ],
#        [ 0.01253438,  1.        ],
#        [-0.28952519,  1.        ],
#        [ 0.35949197,  1.        ],
#        [ 0.60135989,  1.        ],
#        [-0.58477586,  1.        ],
#        [ 0.5537827 ,  1.        ],
#        [-2.25562851,  1.        ],
#        [ 1.28644883,  1.        ],
#        [-0.26159545,  1.        ],
#        [-0.91837665,  1.        ],
#        [ 2.00395042,  1.        ],
#        [ 0.33869495,  1.        ],
#        [-1.72563694,  1.        ],
#        [-0.52646405,  1.        ],
#        [-2.34880304,  1.        ],
#        [-0.49447441,  1.        ],
#        [ 0.970201  ,  1.        ],
#        [ 0.4732398 ,  1.        ],
#        [ 1.56866905,  1.        ]])

# %%
theta=np.random.randn(2,1)
theta
# Out:
# array([[-2.47615981],
#        [ 0.46825958]])

# %% [markdown]
# ### modele

# %%
def model(X,theta):
    return X.dot(theta)

# %%
plt.scatter(x,y)
plt.plot(x,model(X,theta),c='r')

# %% [markdown]
# ### Fct coût

# %%
def cost_fct(X,y,theta):
    m=len(y)
    return 1/(2*m) *np.sum((model(X,theta)-y)**2)

# %%
cost_fct(X,y,theta)
# Out:
# 3428.8167164637603

# %% [markdown]
# ### Gradient & Descente de Grad

# %%
def grad(X,y,theta):
     m=len(y)
     return 1/m * X.T.dot(model(X,theta)-y)

# %%
def gradDes(X,y,theta,learning_rate,n_iter):
    cost_history=np.zeros(n_iter)
    for i in range (0,n_iter):
        theta=theta-learning_rate * grad(X,y,theta)
        cost_history[i]=cost_fct(X,y,theta)
    return theta,cost_history

# %% [markdown]
# ### Machine Learning

# %%
theta_final,cost_history=gradDes(X,y,theta,learning_rate=0.01,n_iter=1000)

# %%
theta_final
# Out:
# array([[86.64862595],
#        [-2.46465632]])

# %%
prediction=model(X,theta_final)
plt.scatter(x,y)
plt.plot(x,prediction,c='r')

# %% [markdown]
# ### courbe d'apprentissage

# %%
plt.plot(range(1000),cost_history)

# %% [markdown]
# ### Le coef de determination

# %% [markdown]
# ![image_2022-03-22_111713.png](data:image/png;base64,...)

# %%
def coef_determination(y,pred):
    u=((y-pred)**2).sum()
    v=((y-y.mean())**2).sum()
    return 1-u/v

# %%
coef_determination(y,prediction)
# Out:
# 0.9825338940790541
